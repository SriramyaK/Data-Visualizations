# %%
import requests

# %%
def raw_random_wiki_page():
    raw_random_wiki_page = requests.get('https://en.wikipedia.org/wiki/Special:Random')
    return raw_random_wiki_page

# %%
raw_random_wiki_page()
# Out:
# <Response [200]>

# %%
wikipedia_link='https://en.wikipedia.org/wiki/Special:Random'

# %%
raw_random_wikipedia_page=requests.get('https://en.wikipedia.org/wiki/Special:Random')
print(raw_random_wikipedia_page)
# Out:
# <Response [200]>

# %%
page1 = raw_random_wikipedia_page.text
print(page1)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>McGrath, Minnesota - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
start_node = page1.find("title>")
end_node = page1.find("</title>")
print('Start:', start_node,'End:',end_node)
# Out:
# Start: 95 End: 131

# %%
wiki_title1 = page1[start_node + 6: end_node]
print(wiki_title1)
# Out:
# McGrath, Minnesota - Wikipedia

# %%
def wiki_title(raw_random_wikipedia_page1):
    page1 = raw_random_wikipedia_page.text
    start_node = page1.find("title>")
    end_node = page1.find("</title>")
    wiki_title1 = page1[start_node + 6: end_node]
    return wiki_title1

# %%
raw_random_wikipedia_page1 = requests.get('https://en.wikipedia.org/wiki/Special:Random')

wiki_title(raw_random_wikipedia_page1)
output1 = wiki_title(raw_random_wikipedia_page1)
output2 = wiki_title(raw_random_wikipedia_page)
wiki_title_list = [output2, output1 ]
print(wiki_title_list[:])
# Out:
# ['McGrath, Minnesota - Wikipedia', 'Amy Maria Hellaby - Wikipedia']

# %%
"""output = requests.get('https://en.wikipedia.org/wiki/Special:Random')
d = {'output1': }
for x in range(10):
    for output in list[output1,output2,:
        wiki_title(output)
        print("finished",output)
#wiki_title_list = [output]
#print(wiki_title_list[:])"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-06a5badef8b4> in <module>()
#       3 for x in range(10):
#       4     for output in range(10):
# ----> 5         wiki_title(output)
#       6         print("finished",output)
#       7 #wiki_title_list = [output]
#
# <ipython-input-20-88659cf9cafd> in wiki_title(raw_random_wikipedia_page)
#       1 def wiki_title(raw_random_wikipedia_page):
# ----> 2     page1 = raw_random_wikipedia_page.text
#       3     start_node = page1.find("title>")
#       4     end_node = page1.find("</title>")
#       5     wiki_title1 = page1[start_node + 6: end_node]
#
# AttributeError: 'int' object has no attribute 'text'

# %%
import ibm_db

# %%
#Replace the placeholder values with the actuals for your Db2 Service Credentials
dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_hostname = "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"            # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_port = "50000"                    # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_uid = "skg34967"                 # e.g. "abc12345"
dsn_pwd = "mzql8kjg^n4t7s3m"                 # e.g. "7dBZ3wWt9XN6$o0J"

# %%
#Create database connection
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  skg34967 on host:  dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net
