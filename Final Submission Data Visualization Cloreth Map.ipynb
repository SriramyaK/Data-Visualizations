# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://cocl.us/sanfran_crime_dataset",index_col=6)
df.head()
# Out:
#             IncidntNum      Category  \
# PdDistrict
# SOUTHERN     120058272   WEAPON LAWS
# SOUTHERN     120058272   WEAPON LAWS
# BAYVIEW      141059263      WARRANTS
# TENDERLOIN   160013662  NON-CRIMINAL
# MISSION      160002740  NON-CRIMINAL
#
#                                                   Descript DayOfWeek  \
# PdDistrict
# SOUTHERN                         POSS OF PROHIBITED WEAPON    Friday
# SOUTHERN    FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# BAYVIEW                                     WARRANT ARREST    Monday
# TENDERLOIN                                   LOST PROPERTY   Tuesday
# MISSION                                      LOST PROPERTY    Friday
#
#                               Date   Time      Resolution  \
# PdDistrict
# SOUTHERN    01/29/2016 12:00:00 AM  11:00  ARREST, BOOKED
# SOUTHERN    01/29/2016 12:00:00 AM  11:00  ARREST, BOOKED
# BAYVIEW     04/25/2016 12:00:00 AM  14:59  ARREST, BOOKED
# ...

# %%
df1 = pd.DataFrame(df.groupby('PdDistrict').count().Descript)
df1 = df1.reset_index()
df1 = df1.rename(index=str,columns={"PdDistrict":"Neighborhood","Descript":"Count"})
df1
# Out:
#   Neighborhood  Count
# 0      BAYVIEW  14303
# 1      CENTRAL  17666
# 2    INGLESIDE  11594
# 3      MISSION  19503
# 4     NORTHERN  20100
# 5         PARK   8699
# 6     RICHMOND   8922
# 7     SOUTHERN  28445
# 8      TARAVAL  11325
# 9   TENDERLOIN   9942

# %%
import numpy as np
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-a4c190b38bb4> in <module>
#       1 import numpy as np
# ----> 2 import folium
#
# ModuleNotFoundError: No module named 'folium'
